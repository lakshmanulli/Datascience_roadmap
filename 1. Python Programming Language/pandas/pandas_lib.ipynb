# %% [markdown]
# # what is pandas
# pandas is an open-source Python library used for data manipulation and analysis.
#
# # What You Can Do with Pandas
# Read data (CSV, Excel, SQL)
#
# Clean data (handle missing values)
#
# Filter and select data
#
# Perform calculations (mean, sum, etc.)
#
# Group and analyze data
#
# Transform data for machine learning

# %%
#install a pandas library with using pip
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import a library
import pandas as pd

# %% [markdown]
# # 🔹 Create Data

# %%
import pandas as pd

# Series
s = pd.Series([10, 20, 30])

# DataFrame
data = {
    "Name": ["Lakshman", "Ravi"],
    "Age": [23, 25]
}
df = pd.DataFrame(data)

print(df)
# Out:
#        Name  Age
# 0  Lakshman   23
# 1      Ravi   25

# %% [markdown]
# ## 🔹 Read Data

# %%
import pandas as pd

df = pd.read_csv("")
